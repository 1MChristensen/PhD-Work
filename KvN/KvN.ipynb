# %% [markdown]
# ### KvN Methods
#
# Solving the IVP
#
# $\frac{\partial x}{\partial t} = -x^2,$ with $x(0)=1$
#
# using Koopman von Neumann methods.

# %% [markdown]
# The following code uses a delta distribution as the initial state

# %%
import numpy as np
import KvN_tools as kvn

# Set up the grid
n_qubits = 11
n_grid = 2**n_qubits
grid_extent = (0,2)
x = np.linspace(*grid_extent, n_grid)

# Set up time
n_steps = 1000
delta = 0.01
t = np.linspace(0, n_steps*delta, n_steps)

# Set up the initial state (delta in this case)
psi = kvn.psi0(x, 1)

# Generate the Hamiltonian to solve generic quadratic ODE, 
# i.e. ax^2 + bx + c where a,b,c are in params list
params = (-1,0,0)
H = kvn.KvN_hamiltonian(x, params)

# Time evolve the state
psi_store = kvn.time_evolution(H, psi, delta, n_steps)

# Plot the results
kvn.plot_evolution(x, psi_store, t)
kvn.plot_mode(x, psi_store, t)
kvn.plot_std(x, psi_store, t)
# Out:
# Initializing the state
# Generating the Hamiltonian
# 100%|██████████| 512/512 [00:09<00:00, 51.52it/s]
# Exponetiating the Hamiltonian
# Time evolution
# 100%|██████████| 999/999 [00:00<00:00, 9780.81it/s]

# %% [markdown]
# The following code uses a Gaussian distribution as the initial state

# %%
# Set up the grid
n_qubits = 11
n_grid = 2**n_qubits
grid_extent = (0,2)
x = np.linspace(*grid_extent, n_grid)

# Set up time
n_steps = 1000
delta = 0.01
t = np.linspace(0, n_steps*delta, n_steps)

# Set up the initial state (delta in this case)
psi = kvn.psi0(x, 1, type='gaussian', std=0.015, n_bins=50)

print(sum(psi))

# Generate the Hamiltonian to solve generic quadratic ODE, 
# i.e. ax^2 + bx + c where a,b,c are in params list
params = (-1,0,0)
H = kvn.KvN_hamiltonian(x, params)

# Time evolve the state
psi_store = kvn.time_evolution(H, psi, delta, n_steps)

# Plot the results
kvn.plot_evolution(x, psi_store, t)
kvn.plot_mode(x, psi_store, t)
kvn.plot_std(x, psi_store, t, log=True)
# Out:
# Initializing the state
# 7.357763437839125
# Generating the Hamiltonian
#   8%|▊         | 161/2048 [02:32<29:46,  1.06it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 20
#      17 # Generate the Hamiltonian to solve generic quadratic ODE,
#      18 # i.e. ax^2 + bx + c where a,b,c are in params list
#      19 params = (-1,0,0)
# ---> 20 H = kvn.KvN_hamiltonian(x, params)
#      22 # Time evolve the state
#      23 psi_store = kvn.time_evolution(H, psi, delta, n_steps)
#
# File ~/PhD/Sketch work/PhD-Work/KvN/KvN_tools.py:36, in KvN_hamiltonian(x, params)
#      34     psi_i = np.zeros(n)
#      35     psi_i[i] = 1
# ---> 36     H[:, i] = hamiltonian(x, psi_i, params)
#      38 return H
#
# File ~/PhD/Sketch work/PhD-Work/KvN/KvN_tools.py:25, in hamiltonian(x, psi, params)
#      23 dx= x[1] - x[0]
#      24 k = 2 * np.pi * np.fft.fftfreq(len(psi), d=dx)
# ---> 25 return 0.5*(P(F(params, x, psi),k) + F(params, x, P(psi,k)))
#
# KeyboardInterrupt:
